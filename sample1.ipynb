# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr_CostPrice=np.array([1500,3000,5000])
arr_daily_sales=np.array([["","Mon","Tue","Wed","Thu"],["Headphones",10,15,8,12],["Smartwatches",5,7,4,6],["Speakers",2,3,2,4]])
print(arr_CostPrice)
print(arr_daily_sales)
# Out:
# [1500 3000 5000]
# [['' 'Mon' 'Tue' 'Wed' 'Thu']
#  ['Headphones' '10' '15' '8' '12']
#  ['Smartwatches' '5' '7' '4' '6']
#  ['Speakers' '2' '3' '2' '4']]
