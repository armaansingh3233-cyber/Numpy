# %% [markdown]
# #### Handling Missing values

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame({
    "Name":["Aman","Saurav","Karan","Shubham",None,"Sameer"],
    "Age":[22,23,None,22,25,23],
    "Marks":[85,None,88,90,56,None]
})
df
# Out:
#       Name   Age  Marks
# 0     Aman  22.0   85.0
# 1   Saurav  23.0    NaN
# 2    Karan   NaN   88.0
# 3  Shubham  22.0   90.0
# 4      NaN  25.0   56.0
# 5   Sameer  23.0    NaN

# %%
df.isnull()
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4   True  False  False
# 5  False  False   True

# %%
df.isnull().sum()
# Out:
# Name     1
# Age      1
# Marks    2
# dtype: int64
