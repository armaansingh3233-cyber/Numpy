# %%
import pandas as pd

df=pd.DataFrame({
    "Name":["Aman","Saurav","Karan","Shubham","Abhishek",None,"Sameer"],
    "Age":[22,23,None,22,25,24,26],
    "Marks":[85,None,88,90,56,72,None],
    "Subject":["Math","Physics","Math","Chemistry","Math","Physics","Chemistrty"]
    
})
df
# Out:
#        Name   Age  Marks     Subject
# 0      Aman  22.0   85.0        Math
# 1    Saurav  23.0    NaN     Physics
# 2     Karan   NaN   88.0        Math
# 3   Shubham  22.0   90.0   Chemistry
# 4  Abhishek  25.0   56.0        Math
# 5       NaN  24.0   72.0     Physics
# 6    Sameer  26.0    NaN  Chemistrty

# %%
df.shape
# Out:
# (7, 4)

# %%
df.dtypes
# Out:
# Name           str
# Age        float64
# Marks      float64
# Subject        str
# dtype: object

# %%
print(df.min)
print(df.mean)
# Out:
# <bound method DataFrame.min of        Name   Age  Marks     Subject
# 0      Aman  22.0   85.0        Math
# 1    Saurav  23.0    NaN     Physics
# 2     Karan   NaN   88.0        Math
# 3   Shubham  22.0   90.0   Chemistry
# 4  Abhishek  25.0   56.0        Math
# 5       NaN  24.0   72.0     Physics
# 6    Sameer  26.0    NaN  Chemistrty>
# <bound method DataFrame.mean of        Name   Age  Marks     Subject
# 0      Aman  22.0   85.0        Math
# 1    Saurav  23.0    NaN     Physics
# 2     Karan   NaN   88.0        Math
# 3   Shubham  22.0   90.0   Chemistry
# 4  Abhishek  25.0   56.0        Math
# 5       NaN  24.0   72.0     Physics
# 6    Sameer  26.0    NaN  Chemistrty>

# %% [markdown]
# #### Exercise 2

# %%
df[["Name","Marks"]]
# Out:
#        Name  Marks
# 0      Aman   85.0
# 1    Saurav    NaN
# 2     Karan   88.0
# 3   Shubham   90.0
# 4  Abhishek   56.0
# 5       NaN   72.0
# 6    Sameer    NaN

# %%
df[df["Marks"]>80]
# Out:
#       Name   Age  Marks    Subject
# 0     Aman  22.0   85.0       Math
# 2    Karan   NaN   88.0       Math
# 3  Shubham  22.0   90.0  Chemistry

# %%
df[(df["Age"]>22.0)&(df["Marks"]>80.0)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Marks, Subject]
# Index: []

# %% [markdown]
# #### Exercise 3

# %%
df.sort_values("Marks")
# Out:
#        Name   Age  Marks     Subject
# 4  Abhishek  25.0   56.0        Math
# 5       NaN  24.0   72.0     Physics
# 0      Aman  22.0   85.0        Math
# 2     Karan   NaN   88.0        Math
# 3   Shubham  22.0   90.0   Chemistry
# 1    Saurav  23.0    NaN     Physics
# 6    Sameer  26.0    NaN  Chemistrty

# %%
first_highest = df["Marks"].nlargest(1).iloc[-1]
second_highest = df["Marks"].nlargest(2).iloc[-1]
lowest=df["Marks"].nsmallest(1).iloc[-1]
print(first_highest)
print(second_highest)
print(lowest)
# Out:
# 90.0
# 88.0
# 56.0

# %% [markdown]
# #### Missing values

# %%
df.isnull().sum()
# Out:
# Name       1
# Age        1
# Marks      2
# Subject    0
# dtype: int64

# %%
missing_marks = df[df["Marks"].isnull()]
print(missing_marks)
# Out:
#      Name   Age  Marks     Subject
# 1  Saurav  23.0    NaN     Physics
# 6  Sameer  26.0    NaN  Chemistrty

# %%
clean_df = df.dropna()
print(clean_df)
# Out:
#        Name   Age  Marks    Subject
# 0      Aman  22.0   85.0       Math
# 3   Shubham  22.0   90.0  Chemistry
# 4  Abhishek  25.0   56.0       Math

# %%
print("Original shape:", df.shape)
print("Clean shape:", clean_df.shape)
print("Rows removed:", df.shape[0] - clean_df.shape[0])
# Out:
# Original shape: (7, 4)
# Clean shape: (3, 4)
# Rows removed: 4
